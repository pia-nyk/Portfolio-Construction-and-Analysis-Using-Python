# %% [markdown]
# ## Random Walk Generation

# %% [markdown]
# In this notebook, we are going to generate random prices and random returns.

# %%
import pandas as pd
import numpy as np

def gbm(n_years=10, n_scenarios=1000, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
    """
    Evolution of a Stock Price using Geometric Brownian Motion Model
    """
    dt = 1/steps_per_year
    n_steps = int(n_years*steps_per_year)
    xi = np.random.normal(size=(n_steps,n_scenarios))
    rets = mu*dt + sigma*np.sqrt(dt)*xi
    rets = pd.DataFrame(rets)
    #to prices
    prices = s_0*(1+rets).cumprod()
    return prices

# %%
p = gbm(10, n_scenarios=3)

# %%
p.head()
# Out:
#             0           1           2
# 0   99.574255   97.214077  103.157119
# 1  100.544421   99.017907  106.390222
# 2  103.289727  101.770292  105.889233
# 3  107.070072  103.718227  109.408139
# 4  106.106973  100.961887  113.651865

# %%
p.plot()

# %%
gbm(n_years=10, n_scenarios=5).plot(figsize=(12,6), legend=True)
